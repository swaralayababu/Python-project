# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ABC_Company.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# Display basic information about the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB
# None

# %%
# Display first few rows of the dataset
print(df.head())
# Display last few rows of the dataset
print(df.tail())
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# ...

# %%
# Replace the 'Height' column with random integers
df['Height'] = np.random.randint(150, 181, size=len(df))

# Display the updated DataFrame
print(df)
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     174     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     154     235
# 2     John Holland  Boston Celtics      30       SG   27     172     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     180     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     176     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     173     203
# 454      Raul Neto       Utah Jazz      25       PG   24     179     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     164     256
# 456    Jeff Withey       Utah Jazz      24        C   26     166     231
# 457       Priyanka       Utah Jazz      34        C   25     179     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df['Salary'].fillna(df['Salary'].mean(), inplace=True)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     174     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     154     235
# 2     John Holland  Boston Celtics      30       SG   27     172     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     180     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     176     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     173     203
# 454      Raul Neto       Utah Jazz      25       PG   24     179     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     164     256
# 456    Jeff Withey       Utah Jazz      24        C   26     166     231
# 457       Priyanka       Utah Jazz      34        C   25     179     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %% [markdown]
# #1.How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
Count = df['Team'].value_counts()
percentage=df['Team'].value_counts(normalize=True)*100
print("Number of employees in each team:",Count,"Percentage",percentage)
# Out:
# Number of employees in each team: Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# ...

# %% [markdown]
# #Visual reprecentation of number of employees working in each team

# %%
plt.figure(figsize=(12, 6))
Team=['New Orleans Pelicans','Memphis Grizzlies','Utah Jaz' ,'New York Knicks','Milwaukee Bucks','Brooklyn Nets','Portland Trail Blazers','Oklahoma City Thunder',
'Denver Nuggets','Washington Wizards','Miami Heat','Charlotte Hornets','Atlanta Hawks','San Antonio Spurs','Houston Rockets','Boston Celtics','Indiana Pacers',           
'Detroit Pistons','Cleveland Cavaliers','Chicago Bulls','Sacramento Kings','Phoenix Suns','Los Angeles Lakers','Los Angeles Clippers','Golden State Warriors',
'Toronto Raptors','Philadelphia 76ers','Dallas Mavericks','Orlando Magic','Minnesota Timberwolves']
Percentage=[4.148472,3.930131,3.493450,3.493450,3.493450,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.275109,3.056769,3.056769]
plt.bar(Team,Percentage,color='y',width=0.5,edgecolor='black')

plt.title('Number of Employees in Each Team')
plt.suptitle("ABC COMPANY PVT LTD")
plt.xlabel('Team')
plt.ylabel('Percentage of employees count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### There are thirty teams, with at least fourteen employees working for each team, according to a review of the ABC company's dataset. The New Orleans Pelicans are the team with the largest number of employees, with 19 people making up 4.148472 of the overall workforce. The teams with the fewest employees are the Minnesota Timberwolves and the Orlando Magic.

# %% [markdown]
# #2.Segregate the employees w.r.t different positions.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Position', data=df,hue='Position', palette="pastel", legend=False)
plt.suptitle("ABC COMPANY PVT LTD")
plt.title('Distribution of Employees Across Positions')
plt.xlabel('Position')
plt.ylabel(' Number of Employees')
plt.show()

# %% [markdown]
# ### ABC Company Ltd. employs 457 individuals in total. The SG position has more workers than the other positions, based on the graphical representation above. Compared to other positions, there are fewer employees in the C role.

# %% [markdown]
# #3.Find from which age group most of the employees belong to.

# %%
df['Age'].value_counts()
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
Age = [24, 25, 27, 23, 26, 28, 30, 29, 22, 31, 20, 21, 33, 32, 34, 36, 35, 37, 38, 40, 39, 19]
Count = [47, 46, 41, 41, 36, 31, 31, 28, 26, 22, 19, 19, 14, 13, 10, 10, 9, 4, 4, 3, 2, 2]
plt.figure(figsize=(12, 6))
plt.bar(Age, Count, color='g', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Number of employees')
plt.suptitle("ABC COMPANY PVT LTD")
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# ## According to the above scatter plot, the majority of ABC Company Ltd.'s employees are between the ages of 23 and 27. There are very few employees who are younger than 18 or older than 38.

# %% [markdown]
# #4.Find out under which team and position, spending in terms of salary is high.

# %%
df.sort_values(by='Salary', inplace=True)
df
# Out:
#                        Name                  Team  Number Position  Age  \
# 109             Kobe Bryant    Los Angeles Lakers      24       SF   37
# 169            LeBron James   Cleveland Cavaliers      23       SF   31
# 33          Carmelo Anthony       New York Knicks       7       SF   32
# 251           Dwight Howard       Houston Rockets      12        C   30
# 339              Chris Bosh            Miami Heat       1       PF   32
# ..                      ...                   ...     ...      ...  ...
# 175            Jordan McRae   Cleveland Cavaliers      12       SG   25
# 135           Alan Williams          Phoenix Suns      15        C   23
# 130            Phil Pressey          Phoenix Suns      25       PG   25
# 291         Orlando Johnson  New Orleans Pelicans       0       SG   27
# 32   Thanasis Antetokounmpo       New York Knicks      43       SF   23
#
#      Height  Weight           College      Salary
# 109     154     212               NaN  25000000.0
# ...

# %%
df2 = df[0:30]
df2
# Out:
#                   Name                   Team  Number Position  Age  Height  \
# 109        Kobe Bryant     Los Angeles Lakers      24       SF   37     154
# 169       LeBron James    Cleveland Cavaliers      23       SF   31     176
# 33     Carmelo Anthony        New York Knicks       7       SF   32     154
# 251      Dwight Howard        Houston Rockets      12        C   30     173
# 339         Chris Bosh             Miami Heat       1       PF   32     150
# 100         Chris Paul   Los Angeles Clippers       3       PG   31     153
# 414       Kevin Durant  Oklahoma City Thunder      35       SF   27     179
# 164       Derrick Rose          Chicago Bulls       1       PG   27     179
# 349        Dwyane Wade             Miami Heat       3       SG   34     176
# 294  LaMarcus Aldridge      San Antonio Spurs      12       PF   30     151
# 174         Kevin Love    Cleveland Cavaliers       0       PF   27     168
# ...

# %%
Top_spending_team_position = df2.groupby(['Team', 'Position'])['Salary'].sum().idxmax()
print(f'Team and Position with High Salary Spending: {Top_spending_team_position}')
team_position_salary = df2.groupby(['Team', 'Position'])['Salary'].sum().reset_index()
# Out:
# Team and Position with High Salary Spending: ('Los Angeles Lakers', 'SF')

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Team', y='Salary', hue='Position', data=team_position_salary,)
plt.suptitle("ABC COMPANY PVT LTD")
plt.title('Salary Spending by Team and Position')
plt.xticks(rotation=90)
plt.xlabel('Team')
plt.ylabel('Total Salary Spending')
plt.show()

# %% [markdown]
# ### Based on the analysis, It's evident that the Los Angeles Lakers, Cleveland Cavaliers, and New York Knicks employees in the position of SF have the highest salaries.

# %% [markdown]
# #5.Find if there is any correlation between age and salary , represent it visually.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x='Age', y='Salary', data=df,color='r', edgecolor='black', alpha=0.8)
plt.xlabel('Age')
plt.ylabel('Salary')
plt.suptitle("ABC COMPANY LTD")
plt.title('Violin Plot of Age vs Salary')
plt.show()

# %% [markdown]
# ### This dataset included 57 ABC Company workers' personal data. The age of the employee and their pay were found to positively correlate with one another. Salary was plotted on the x-axis and age was placed on the y-axis in this scatter plot. It's evident that as people age, their salaries rise as well. However, after the age of 35, pay gradually declines.
